# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisCollazos/Se-ales/blob/master/clase1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np             #Libreria numpy
import matplotlib.pyplot as plt #Libreria pyplot

#INGRESO
a=-5
b=5
dt=0.1
sigma=0
omega=0

#PROCEDIMIENTO
t=np.arange(a,b,dt)
s=complex(sigma,omega)
senal=np.exp(s*t)

#SALIDA
plt.figure(1)
plt.plot(t,np.real(senal),label = 'real')
plt.plot(t,np.imag(senal),label = 'imaginaria')
plt.xlabel('t')
plt.ylabel('x(t)')
plt.legend()
plt.margins(0.1)
plt.title('e^('+str(sigma)+'+'+str(omega)+'j)')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
sigma=-1
omega=1

#PROCEDIMIENTO
t=np.arange(a,b,dt)
s=complex(sigma,omega)
senal=np.exp(s*t)

#SALIDA
plt.figure(1)
plt.plot(t,np.real(senal),label = 'real')
plt.plot(t,np.imag(senal),label = 'imaginaria')
plt.xlabel('t')
plt.ylabel('x(t)')
plt.legend()
plt.margins(0.1)
plt.title('e^('+str(sigma)+'+'+str(omega)+'j)')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
sigma=0
omega=1

#PROCEDIMIENTO
s=complex(sigma,omega)
senal=np.exp(s*t)

#SALIDA
plt.figure(4)
plt.plot(np.real(senal),np.imag(senal),label = 'complejo')
plt.xlabel('real')
plt.ylabel('imaginario')
plt.legend()
plt.margins(0.1)
plt.title('e^('+str(sigma)+'+'+str(omega)+'j)')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
  import scipy.integrate as integrate
  
  W=1
  a=0.8
  b=0
  c=4*2*np.pi
  dte=0.0005
  
  te=np.arange(b,c,dte)
  xe=np.exp(-a*te)
  
  cuadradoxe=xe**2  #elevado(**)
  energiaxe=integrate.simps(cuadradoxe,te)
  
  print('la energia de xee s:',energiaxe)
  
  plt.plot(te,xe,label='xe')
  plt.fill_between(te,0,cuadradoxe,color='lightgreen')
  plt.plot(te,cuadradoxe,'g--',label='xe^2')
  plt.xlabel('t')
  plt.legend()
  plt.show
# Out:
# la energia de xee s: 0.6250000000133293
# <function matplotlib.pyplot.show>

# %%
w=1
a=0
b=2*np.pi
dte=0.005
Q=0
A=2

T=2*np.pi/w
te=np.arange(a,b,dte)
xe=A*np.cos(W*te+Q)

cuadradoxe=xe**2  #elevado(**)
energiaxe=integrate.simps(cuadradoxe,te)

potenciaxe=(1/T)*energiaxe
print('la potencia de xe es:',potenciaxe)

plt.plot(te,xe,label='xe')
plt.fill_between(te,0,cuadradoxe,color='lightgreen')
plt.plot(te,cuadradoxe,'g--',label='xe^2')
plt.xlabel('t')
plt.legend()
plt.show
# Out:
# la potencia de xe es: 1.9979721773265833
# <function matplotlib.pyplot.show>
